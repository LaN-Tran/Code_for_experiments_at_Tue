# %% [markdown]
# # Libs

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 20250610
#
# Illustrate the collected data in the folder `../codes/exp_data/20250610`

# %% [markdown]
# ## case 1
#
# - 1. ground vg, change vd to dope/ de-dope the pedot channel
#
# - 2. compare the impact of different resistor between gnd and vg (i.e gnd - resistor - gate) on the dope/ de-dope process of the pedot channel.
#
# - 3. cover the files from `ecram_9.csv` to `ecram_16.csv`

# %%
    # case: write (Vg=0, Vd=-0.2), read (Vd = -0.1)
        ## load files
r1M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_9.csv")
r2M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_11.csv")
r3M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_13.csv")
r100M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_15.csv")

# %%
r1M_t = r1M['time']
r1M_i = r1M['i']

r2M_t = r2M['time']
r2M_i = r2M['i']

r3M_t = r3M['time']
r3M_i = r3M['i']

r100M_t = r100M['time']
r100M_i = r100M['i']

# %%
plt.title("write (Vg=0, Vd=-0.2), read (Vd = -0.1)")
plt.plot(r1M_t, r1M_i, label ='r1M')
plt.plot(r2M_t, r2M_i, label ='r2M')
plt.plot(r3M_t, r3M_i, label ='r3M')
plt.plot(r100M_t, r100M_i, label ='r100M')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %%
# case: write (Vg=0, Vd=0.2), read (Vd = -0.1)
        ## load files
r1M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_10.csv")
r2M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_12.csv")
r3M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_14.csv")
r100M = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_16.csv")

# %%
r1M_t = r1M['time']
r1M_i = r1M['i']

r2M_t = r2M['time']
r2M_i = r2M['i']

r3M_t = r3M['time']
r3M_i = r3M['i']

r100M_t = r100M['time']
r100M_i = r100M['i']

# %%
plt.title("write (Vg=0, Vd=0.2), read (Vd = -0.1)")
plt.plot(r1M_t, r1M_i, label ='r1M')
plt.plot(r2M_t, r2M_i, label ='r2M')
plt.plot(r3M_t, r3M_i, label ='r3M')
plt.plot(r100M_t, r100M_i, label ='r100M')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %%
# case: for 1M, write (Vg=0, Vd=0.2 / Vd = -0.2), 
# read (Vd = -0.1)
        ## load files
r1M_vgd_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_9.csv")
r1M_vgd_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_10.csv")

# %%
r1M_vgd_p_t = r1M_vgd_p['time']
r1M_vgd_p_i = r1M_vgd_p['i']

r1M_vgd_n_t = r1M_vgd_n['time']
r1M_vgd_n_i = r1M_vgd_n['i']

# %%
plt.title("write (Vg=0, Vd=0.2 / -0.2), read (Vd = -0.1)")
plt.plot(r1M_vgd_p_t, r1M_vgd_p_i, label ='r1M, vgd positive')
plt.plot(r1M_vgd_n_t, r1M_vgd_n_i, label ='r1M vgd negative')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %%
# case: for 1M, write (Vg=0, Vd=0.2 / Vd = -0.2), 
# read (Vd = -0.1)
        ## load files
r2M_vgd_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_11.csv")
r2M_vgd_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_12.csv")

r2M_vgd_p_t = r2M_vgd_p['time']
r2M_vgd_p_i = r2M_vgd_p['i']

r2M_vgd_n_t = r2M_vgd_n['time']
r2M_vgd_n_i = r2M_vgd_n['i']

plt.title("write (Vg=0, Vd=0.2 / -0.2), read (Vd = -0.1)")
plt.plot(r2M_vgd_p_t, r2M_vgd_p_i, label ='r2M, vgd positive')
plt.plot(r2M_vgd_n_t, r2M_vgd_n_i, label ='r2M vgd negative')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %%
# case: for 1M, write (Vg=0, Vd=0.2 / Vd = -0.2), 
# read (Vd = -0.1)
        ## load files
r3M_vgd_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_13.csv")
r3M_vgd_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_14.csv")

r3M_vgd_p_t = r3M_vgd_p['time']
r3M_vgd_p_i = r3M_vgd_p['i']

r3M_vgd_n_t = r3M_vgd_n['time']
r3M_vgd_n_i = r3M_vgd_n['i']

plt.title("write (Vg=0, Vd=0.2 / -0.2), read (Vd = -0.1)")
plt.plot(r3M_vgd_p_t, r3M_vgd_p_i, label ='r3M, vgd positive')
plt.plot(r3M_vgd_n_t, r3M_vgd_n_i, label ='r3M vgd negative')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %%
# case: for 1M, write (Vg=0, Vd=0.2 / Vd = -0.2), 
# read (Vd = -0.1)
        ## load files
r100M_vgd_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_15.csv")
r100M_vgd_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_16.csv")

r100M_vgd_p_t = r100M_vgd_p['time']
r100M_vgd_p_i = r100M_vgd_p['i']

r100M_vgd_n_t = r100M_vgd_n['time']
r100M_vgd_n_i = r100M_vgd_n['i']

plt.title("write (Vg=0, Vd=0.2 / -0.2), read (Vd = -0.1)")
plt.plot(r100M_vgd_p_t, r100M_vgd_p_i, label ='r100M, vgd positive')
plt.plot(r100M_vgd_n_t, r100M_vgd_n_i, label ='r100M vgd negative')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %% [markdown]
# ## Case 2
#
# - investigate VGD impact on conductance of channel: `ecram_7.csv` and `ecram_8.csv`

# %%
save_path = "C:/Users/20245580/Documents/Meetings/WorkProgressImgs"

# %%
vgd_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_8.csv")
vgd_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250610/ecram_7.csv")

vgd_p_t = vgd_p['time']
vgd_p_i = vgd_p['i']

vgd_n_t = vgd_n['time']
vgd_n_i = vgd_n['i']

plt.title("write (Vg=0, Vd=0.1 / -0.1), read (Vd = -0.1)")
plt.plot(vgd_p_t, vgd_p_i, label ='vgd positive')
plt.plot(vgd_n_t, vgd_n_i, label ='vgd negative')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()
# plt.savefig(save_path + "/vgd_ids")

# %% [markdown]
# # 20250611

# %%
tc_oect5 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/transfer_curve_OECT5.csv")
tc_oect6 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/transfer_curve_OECT6.csv")
tc_oect8 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/transfer_curve_OECT8.csv")
tc_oect10 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/transfer_curve_OECT10.csv")

tc_oect5_i = tc_oect5['i_channel']
tc_oect5_v = tc_oect5['v_gate']

tc_oect6_i = tc_oect6['i_channel']
tc_oect6_v = tc_oect6['v_gate']

tc_oect8_i = tc_oect8['i_channel']
tc_oect8_v = tc_oect8['v_gate']

tc_oect10_i = tc_oect10['i_channel']
tc_oect10_v = tc_oect10['v_gate']

plt.title("transfer curve @ Vd = -0.1")
plt.plot(tc_oect5_v, tc_oect5_i, label ='oect 5')
plt.plot(tc_oect6_v, tc_oect6_i, label ='oect 6')
plt.plot(tc_oect8_v, tc_oect8_i, label ='oect 8')
plt.plot(tc_oect10_v, tc_oect10_i, label ='oect 10')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
plt.legend()

# %%
er_oect5_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT5_1.csv")
er_oect5_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT5_2.csv")

er_oect6_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT6_1.csv")
er_oect6_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT6_2.csv")

er_oect8_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT8_1.csv")
er_oect8_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT8_2.csv")

er_oect10_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT10_1.csv")
er_oect10_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250611/ecram_OECT10_2.csv")

er_oect5_p_t = er_oect5_p['time']
er_oect5_p_i = er_oect5_p['i']

er_oect5_n_t = er_oect5_n['time']
er_oect5_n_i = er_oect5_n['i']

er_oect6_p_t = er_oect6_p['time']
er_oect6_p_i = er_oect6_p['i']

er_oect6_n_t = er_oect6_n['time']
er_oect6_n_i = er_oect6_n['i']

er_oect8_p_t = er_oect8_p['time']
er_oect8_p_i = er_oect8_p['i']

er_oect8_n_t = er_oect8_n['time']
er_oect8_n_i = er_oect8_n['i']

er_oect10_p_t = er_oect10_p['time']
er_oect10_p_i = er_oect10_p['i']

er_oect10_n_t = er_oect10_n['time']
er_oect10_n_i = er_oect10_n['i']

plt.title("write (Vg=0, Vd=0.4 / -0.4), read (Vd = -0.1)")
plt.plot(er_oect5_p_t, er_oect5_p_i, '--', label ='vgd positive, oect5')
plt.plot(er_oect6_p_t, er_oect6_p_i, '--', label ='vgd positive, oect6')
plt.plot(er_oect8_p_t, er_oect8_p_i, '--', label ='vgd positive, oect8')
plt.plot(er_oect10_p_t, er_oect10_p_i, '--', label ='vgd positive, oect10')

plt.plot(er_oect5_n_t, er_oect5_n_i, '-', label ='vgd negative, oect5')
plt.plot(er_oect6_n_t, er_oect6_n_i, '-', label ='vgd negative, oect6')
plt.plot(er_oect8_n_t, er_oect8_n_i, '-', label ='vgd negative, oect8')
plt.plot(er_oect10_n_t, er_oect10_n_i, '-', label ='vgd negative, oect10')
plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %% [markdown]
# # 20250613

# %%
er_oect8_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250613/exp_3/OECT8_2.csv")
er_oect8_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250613/exp_3/OECT8_1.csv")

er_oect8_r4M_n = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250613/exp_3/OECT8_4M_2.csv")
er_oect8_r4M_p = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250613/exp_3/OECT8_4M_1.csv")

er_oect8_p_t = er_oect8_p['time']
er_oect8_p_i = er_oect8_p['i']

er_oect8_n_t = er_oect8_n['time']
er_oect8_n_i = er_oect8_n['i']

er_oect8_r4M_p_t = er_oect8_r4M_p['time']
er_oect8_r4M_p_i = er_oect8_r4M_p['i']

er_oect8_r4M_n_t = er_oect8_r4M_n['time']
er_oect8_r4M_n_i = er_oect8_r4M_n['i']

plt.title("write (Vg=0, Vd=0.4 / -0.4), read (Vd = -0.1)")
plt.plot(er_oect5_p_t, er_oect5_p_i, '--', label ='vgd positive, oect5')
plt.plot(er_oect6_p_t, er_oect6_p_i, '--', label ='vgd positive, oect6')


plt.plot(er_oect5_n_t, er_oect5_n_i, '-', label ='vgd negative, oect5')
plt.plot(er_oect6_n_t, er_oect6_n_i, '-', label ='vgd negative, oect6')

plt.xlabel("time [s]")
plt.ylabel("Id [A]")
plt.legend()

# %% [markdown]
# # 20250617

# %% [markdown]
# ## Filter noisy signal
#
# - 1. Scipy
#
# **REFERENCE**
#
# [1] https://www.daanmichiels.com/blog/2017/10/filtering-eeg-signals-using-scipy/ (NOT WORKING IN THIS CASE)
#
# [2] https://scipy-cookbook.readthedocs.io/items/KalmanFiltering.html

# %%
from scipy import signal

# %%
filter = signal.firwin(400, [0.01, 0.06], pass_zero=False)

# %%
stdp_post_pre = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250617/stdp_2.csv")

stdp_post_pre_t = stdp_post_pre['time']
stdp_post_pre_i = stdp_post_pre['i']
stdp_post_pre_v = stdp_post_pre['v']

# %%
filtered_v = signal.convolve(stdp_post_pre_v, filter, mode='same')

# %%
filtered_i = signal.convolve(stdp_post_pre_i, filter, mode='same')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)

ax1.set_xlabel('time [s]')
ax1.set_ylabel('v [V], no filter')
ax1.grid()

ax2.set_xlabel('time [s]')
ax2.set_ylabel('v [V], filtered')
ax2.grid()
        
ax1.plot(stdp_post_pre_t, stdp_post_pre_v)
ax2.plot(stdp_post_pre_t, filtered_v)

# %% [markdown]
# # 20250707
#
# Illustrate the collected data in the folder `../codes/exp_data/20250707`

# %% [markdown]
# ## individual

# %%
pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")


er_t = pedotpss_kcl_2min['time']
er_i = pedotpss_kcl_2min['i_channel']
er_v = pedotpss_kcl_2min['v_gate']


fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
# ref 
# [1] https://www.geeksforgeeks.org/python/how-to-set-a-single-main-title-for-all-the-subplots-in-matplotlib/
fig.suptitle('channel material pedotpss, dedoping', fontsize=18)

ax1.set_xlabel('time [s]')
ax1.set_ylabel('v gate [V]')
ax1.grid()

ax2.set_xlabel('time [s]')
ax2.set_ylabel('i channel [A]')
ax2.grid()

start= 0
end = len(er_t) - 15000
ax1.plot(er_t[start:end], er_v[start:end])
ax2.plot(er_t[start:end], abs(er_i)[start:end])

# %%
pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")


er_t = pedotpss_kcl_2min['time']
er_i = pedotpss_kcl_2min['i_channel']
er_v = pedotpss_kcl_2min['v_gate']


fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
# ref 
# [1] https://www.geeksforgeeks.org/python/how-to-set-a-single-main-title-for-all-the-subplots-in-matplotlib/
fig.suptitle('channel material pedotpss, doping', fontsize=18)

ax1.set_xlabel('time [s]')
ax1.set_ylabel('v gate [V]')
ax1.grid()

ax2.set_xlabel('time [s]')
ax2.set_ylabel('i channel [A]')
ax2.grid()
        
start= 12000
end = len(er_t) - 1000
ax1.plot(er_t[start:end], er_v[start:end])
ax2.plot(er_t[start:end], abs(er_i)[start:end])

# %%
pedotpssC186_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_1.csv")


er_t = pedotpssC186_kcl_2min['time']
er_i = pedotpssC186_kcl_2min['i_channel']
er_v = pedotpssC186_kcl_2min['v_gate']


fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.suptitle('channel material pedotpss + 18C6 (crown), dedoping', fontsize=18)
ax1.set_xlabel('time [s]')
ax1.set_ylabel('v gate [V]')
ax1.grid()

ax2.set_xlabel('time [s]')
ax2.set_ylabel('i channel [A]')
ax2.grid()
        
ax1.plot(er_t, er_v)
ax2.plot(er_t, abs(er_i))

# %%
pedotpssC186_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_2.csv")


er_t = pedotpssC186_kcl_2min['time']
er_i = pedotpssC186_kcl_2min['i_channel']
er_v = pedotpssC186_kcl_2min['v_gate']


fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.suptitle('channel material pedotpss + 18C6 (crown), doping', fontsize=18)
ax1.set_xlabel('time [s]')
ax1.set_ylabel('v gate [V]')
ax1.grid()

ax2.set_xlabel('time [s]')
ax2.set_ylabel('i channel [A]')
ax2.set_ylim(3.1e-4, 3.12e-4)
# ax2.set_yscale("log")
ax2.grid()

start = 10000
end = len(er_t) -1
ax1.plot(er_t[start:end], er_v[start:end])
ax2.plot(er_t[start:end], abs(er_i)[start:end])

# %% [markdown]
# ## comparison

# %%
pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")
pedotpssC186_kcl_2min_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_1.csv")

er_pedotpss_t = pedotpss_kcl_2min['time']
er_pedotpss_i = pedotpss_kcl_2min['i_channel']

er_pedotpssC186_1_t = pedotpssC186_kcl_2min_1['time']
er_pedotpssC186_1_i = pedotpssC186_kcl_2min_1['i_channel']

plt.figure()
plt.title("comparison (keeping the magnitude, only dc shift)")
start = 0
end = len(er_pedotpss_i) -14000
plt.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 145)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_1_i) -1
plt.plot((er_pedotpssC186_1_t)[start:end], abs(er_pedotpssC186_1_i/1e-6)[start:end], '--', label ='pedotpss 18c6, dedoping')

# plt.ylim(305, 315) # (zoom-in purpose)
plt.xlabel("time [s]")
plt.ylabel("Id [uA]")
plt.yscale("linear")
plt.legend()

# %%
pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")
pedotpssC186_kcl_2min_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_2.csv")

er_pedotpss_t = pedotpss_kcl_2min['time']
er_pedotpss_i = pedotpss_kcl_2min['i_channel']

er_pedotpssC186_2_t = pedotpssC186_kcl_2min_2['time']
er_pedotpssC186_2_i = pedotpssC186_kcl_2min_2['i_channel']

plt.figure()
plt.title("comparison (keeping the magnitude, only dc shift)")
start = 10000
end = len(er_pedotpss_i) -1000
plt.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 121)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_2_i) -1
plt.plot((er_pedotpssC186_2_t + 600)[start:end], abs(er_pedotpssC186_2_i/1e-6)[start:end], '--', label ='pedotpss 18c6, doping')

# plt.ylim(310, 313)
plt.xlabel("time [s]")
plt.ylabel("Id [uA]")
plt.yscale("linear")
plt.legend()

# %%
# reference: 
# [1] https://www.youtube.com/watch?v=pvhaAOumO6s
# [2] https://matplotlib.org/stable/gallery/subplots_axes_and_figures/axes_demo.html#sphx-glr-gallery-subplots-axes-and-figures-axes-demo-py
pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")
pedotpssC186_kcl_2min_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_1.csv")

er_pedotpss_t = pedotpss_kcl_2min['time']
er_pedotpss_i = pedotpss_kcl_2min['i_channel']

er_pedotpssC186_1_t = pedotpssC186_kcl_2min_1['time']
er_pedotpssC186_1_i = pedotpssC186_kcl_2min_1['i_channel']

# main figure (for ploting the zoom-in view)
fig, out = plt.subplots(figsize=(10,4))
out.set_title("comparison (keeping the magnitude, only dc shift)")
start = 0
end = len(er_pedotpss_i) -14000
out.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 145)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_1_i) -1
out.plot((er_pedotpssC186_1_t)[start:end], abs(er_pedotpssC186_1_i/1e-6)[start:end], '--', label ='pedotpss 18c6, dedoping')

out.set_xlabel("time [s]")
out.set_ylabel("Id [uA]")
out.set_yscale("linear")

starting_point_y_cordinate = 305
end_point_y_cordinate = 315
starting_point_x_cordinate = 200
end_point_x_cordinate = 400

out.set_ylim(starting_point_y_cordinate, end_point_y_cordinate)
out.set_xlim(starting_point_x_cordinate, end_point_x_cordinate)

out.legend()

# inset of the main figure = the original view
inset = fig.add_axes([0.6, 0.3, 0.2, 0.2]) # [left, bottom, width, height] = % of the fig
                               # 0.5= 50 % of the fig x axis, 0.5= 50 % of the fig y axis, 0.2 = 20 % of fig width, etc  
end = len(er_pedotpss_i) -14000
inset.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 145)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_1_i) -1
inset.plot((er_pedotpssC186_1_t)[start:end], abs(er_pedotpssC186_1_i/1e-6)[start:end], '--', label ='pedotpss 18c6, dedoping')


# marking the zoom-in region
width = end_point_x_cordinate - starting_point_x_cordinate
height = end_point_y_cordinate - starting_point_y_cordinate
rect = plt.Rectangle((starting_point_x_cordinate,starting_point_y_cordinate), width, height, linewidth = 1, edgecolor = 'b', facecolor = 'None') # (starting point position, width, height)
inset.add_patch(rect)

# %%
# reference: 
# [1] https://www.youtube.com/watch?v=pvhaAOumO6s
# [2] https://matplotlib.org/stable/gallery/subplots_axes_and_figures/axes_demo.html#sphx-glr-gallery-subplots-axes-and-figures-axes-demo-py

pedotpss_kcl_2min = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_pedotpss_KCl_2min.csv")
pedotpssC186_kcl_2min_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250707/ecram_Shiv_18C6Pedot_KCl_2min_2.csv")

er_pedotpss_t = pedotpss_kcl_2min['time']
er_pedotpss_i = pedotpss_kcl_2min['i_channel']

er_pedotpssC186_2_t = pedotpssC186_kcl_2min_2['time']
er_pedotpssC186_2_i = pedotpssC186_kcl_2min_2['i_channel']


# main figure (for ploting the zoom-in view)
fig, out = plt.subplots(figsize=(10,4))
out.set_title("comparison (keeping the magnitude, only dc shift)")
start = 10000
end = len(er_pedotpss_i) -1000
out.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 121)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_2_i) -1
out.plot((er_pedotpssC186_2_t + 600)[start:end], abs(er_pedotpssC186_2_i/1e-6)[start:end], '-', label ='pedotpss 18c6, doping')


out.set_xlabel("time [s]")
out.set_ylabel("Id [uA]")
out.set_yscale("linear")

# plt.ylim(310, 313)
starting_point_y_cordinate = 310
end_point_y_cordinate = 320
starting_point_x_cordinate = 800
end_point_x_cordinate = 1000

out.set_ylim(starting_point_y_cordinate, end_point_y_cordinate)
out.set_xlim(starting_point_x_cordinate, end_point_x_cordinate)

out.legend()

# inset of the main figure = the original view
inset = fig.add_axes([0.4, 0.3, 0.2, 0.2]) # [left, bottom, width, height] = % of the fig
                               # 0.5= 50 % of the fig x axis, 0.5= 50 % of the fig y axis, 0.2 = 20 % of fig width, etc  
start = 10000
end = len(er_pedotpss_i) -1000
inset.plot(er_pedotpss_t[start:end], (abs(er_pedotpss_i/1e-6) + 121)[start:end], '--', label ='pedotpss')
start = 0
end = len(er_pedotpssC186_2_i) -1
inset.plot((er_pedotpssC186_2_t + 600)[start:end], abs(er_pedotpssC186_2_i/1e-6)[start:end], '--', label ='pedotpss 18c6, doping')

# marking the zoom-in region
width = end_point_x_cordinate - starting_point_x_cordinate
height = end_point_y_cordinate - starting_point_y_cordinate
rect = plt.Rectangle((starting_point_x_cordinate,starting_point_y_cordinate), width, height, linewidth = 1, edgecolor = 'b', facecolor = 'None') # (starting point position, width, height)
inset.add_patch(rect)

# %% [markdown]
# # 20250703
#
# STDP: keithley (ampere meter), AD3 (input waves), oscilloscope (input wave monitor)

# %%
stdp_dg_agcl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250703/stdp_oect6_dg_AgAgCl.csv")

stdp_t = stdp_dg_agcl['time']
stdp_i = stdp_dg_agcl['i_channel']

plt.figure()
plt.title("stdp")
start = 0
end = len(stdp_t) -17500
plt.plot(stdp_t[start:end], stdp_i[start:end], '--', label ='stdp')

# plt.ylim(310, 313)
plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.legend()

# %%
stdp_dg_agcl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250703/stdp_oect6_gd_AgAgCl.csv")

stdp_t = stdp_dg_agcl['time']
stdp_i = stdp_dg_agcl['i_channel']

plt.figure()
plt.title("stdp")
start = 0
end = len(stdp_t) -1
plt.plot(stdp_t[start:end], stdp_i[start:end], '--', label ='stdp')

# plt.ylim(310, 313)
plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.legend()

# %%
stdp_dg_pedotgate = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250703/stdp_oect6_dg.csv")

stdp_t = stdp_dg_pedotgate['time']
stdp_i = stdp_dg_pedotgate['i_channel']

plt.figure()
plt.title("stdp")
start = 0
end = len(stdp_t) -1
plt.plot(stdp_t[start:end], stdp_i[start:end], '--', label ='stdp')

# plt.ylim(310, 313)
plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.legend()

# %%
stdp_dg_pedotgate = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250703/stdp_oect6.csv")

stdp_t = stdp_dg_pedotgate['time']
stdp_i = stdp_dg_pedotgate['i_channel']

plt.figure()
plt.title("stdp")
start = 0
end = len(stdp_t) -1
plt.plot(stdp_t[start:end], stdp_i[start:end], '--', label ='stdp')

# plt.ylim(310, 313)
plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.legend()

# %% [markdown]
# # 20250711

# %% [markdown]
# ## wavegen signals for stdp

# %%
# plot wavegen signals
stdp_dg_pedotgate = pd.read_csv("C:/Users/20245580/Documents/Lab/EC_RAM/20250711/NewFile2_mod.csv", delimiter=',')

# %%
stdp_dg_pedotgate
# Out:
#                X    CH1    CH2  Unnamed: 3
# 0              0  0.204  0.004         NaN
# 1              1  0.208  0.004         NaN
# 2              2  0.208  0.004         NaN
# 3              3  0.208  0.004         NaN
# 4              4  0.208  0.004         NaN
# ...          ...    ...    ...         ...
# 5999995  5999995  0.004  0.004         NaN
# 5999996  5999996  0.004  0.004         NaN
# 5999997  5999997  0.004  0.000         NaN
# 5999998  5999998  0.004  0.000         NaN
# 5999999  5999999  0.004  0.004         NaN
#
# [6000000 rows x 4 columns]

# %%
# The Rigol oscilloscope sampling frequency is 250e+3 samples/second
sampling_freq = 250e+3 # [Hz]
stdp_t = stdp_dg_pedotgate['X'] * (1/sampling_freq)
stdp_i = stdp_dg_pedotgate['CH1']
stdp_i2 = stdp_dg_pedotgate['CH2']

plt.figure()
plt.title("stdp")
start = 0  # 0 # 400000
end =  - 1 # -11590000
plt.plot(stdp_t[start:end], stdp_i[start:end], '-', label ='pulse @ drain')
plt.plot(stdp_t[start:end], stdp_i2[start:end], '-', label ='pulse @ gate')

# plt.ylim(310, 313)
plt.xlim(10.56, 10.58)

plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.grid()
plt.legend()
# Out:
# c:\Users\20245580\AppData\Local\anaconda3\envs\microcontroller\lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\20245580\AppData\Local\anaconda3\envs\microcontroller\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure()
plt.title("stdp")
start = 0  # 0 # 400000
end =  - 1 # -11590000
plt.plot(stdp_t[start:end], stdp_i[start:end], '-', label ='pulse @ drain')
plt.plot(stdp_t[start:end], stdp_i2[start:end], '-', label ='pulse @ gate')

# plt.ylim(310, 313)
# plt.xlim(10.56, 10.58)

plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# reference: 
# [1] https://www.youtube.com/watch?v=pvhaAOumO6s
# [2] https://matplotlib.org/stable/gallery/subplots_axes_and_figures/axes_demo.html#sphx-glr-gallery-subplots-axes-and-figures-axes-demo-py

# The Rigol oscilloscope sampling frequency is 250e+3 samples/second
sampling_freq = 250e+3 # [Hz]
stdp_t = stdp_dg_pedotgate['X'] * (1/sampling_freq)
stdp_i = stdp_dg_pedotgate['CH1']
stdp_i2 = stdp_dg_pedotgate['CH2']


# main figure (for ploting the zoom-in view)
fig, out = plt.subplots(figsize=(10,4))
out.set_title("example of signals at drain and gate during write phase")
start = 0  # 0 # 400000
end =  - 1 # -11590000
out.plot(stdp_t[start:end], stdp_i[start:end], '-', label ='pulse @ drain')
out.plot(stdp_t[start:end], stdp_i2[start:end], '-', label ='pulse @ gate')


out.set_xlabel("time [s]")
out.set_ylabel("voltage [V]")
out.set_yscale("linear")

# plt.ylim(310, 313)
starting_point_y_cordinate = -0.01
end_point_y_cordinate = 0.2
starting_point_x_cordinate = 10.5625
end_point_x_cordinate = 10.5750

# out.set_ylim(starting_point_y_cordinate, end_point_y_cordinate)
out.set_xlim(starting_point_x_cordinate, end_point_x_cordinate)
out.grid()
out.legend()


# inset of the main figure = the original view
inset = fig.add_axes([0.4, 0.3, 0.2, 0.2]) # [left, bottom, width, height] = % of the fig
                               # 0.5= 50 % of the fig x axis, 0.5= 50 % of the fig y axis, 0.2 = 20 % of fig width, etc  
start = 0
end = -1
inset.plot(stdp_t[start:end], stdp_i[start:end], '-', label ='pulse @ drain')
inset.plot(stdp_t[start:end], stdp_i2[start:end], '-', label ='pulse @ gate')
inset.set_xlim(10.5, 11)

# marking the zoom-in region
width = end_point_x_cordinate - starting_point_x_cordinate
height = end_point_y_cordinate - starting_point_y_cordinate
rect = plt.Rectangle((starting_point_x_cordinate,starting_point_y_cordinate), width, height, linewidth = 2, edgecolor = 'b', facecolor = 'None') # (starting point position, width, height)
inset.add_patch(rect)
# Out:
# c:\Users\20245580\AppData\Local\anaconda3\envs\microcontroller\lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# c:\Users\20245580\AppData\Local\anaconda3\envs\microcontroller\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## stdp testing

# %% [markdown]
# ### effect of gate only during write phase

# %%
stdp_gate_only = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/ecram_keithley_AD3_oect6_2.csv")

# %%
stdp_gate_only_t = stdp_gate_only['time']
stdp_gate_only_i = stdp_gate_only['i_channel']

# %%
plt.figure()
plt.title("pulse @ gate only during write phase")
start = 0  # 0 # 400000
end =  - 1 # -11590000
plt.plot(stdp_gate_only_t[start:end], stdp_gate_only_i[start:end], '.', label ='Id during read phase')

# plt.ylim(310, 313)
# plt.xlim(10.56, 10.58)

plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.grid()
plt.legend()

# %% [markdown]
# ### effect of drain only during write phase

# %%
stdp_drain_only = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/ecram_keithley_AD3_oect6_3.csv")

# %%
stdp_drain_only_t = stdp_drain_only['time']
stdp_drain_only_i = stdp_drain_only['i_channel']

# %%
plt.figure()
plt.title("pulse @ drain only during write phase")
start = 0  # 0 # 400000
end =  - 1 # -11590000
plt.plot(stdp_drain_only_t[start:end], stdp_drain_only_i[start:end], '.', label ='Id during read phase')

# plt.ylim(310, 313)
# plt.xlim(10.56, 10.58)

plt.xlabel("time [s]")
plt.ylabel("Id")
plt.yscale("linear")
plt.grid()
plt.legend()

# %% [markdown]
# ## oect6

# %% [markdown]
# ### transfer curve

# %%
tc_vdminus100mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_vdminus100mV.csv")
tc_vdminus200mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_vdminus200mV.csv")
tc_vdminus300mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_vdminus300mV.csv")
tc_vdminus400mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_vdminus400mV.csv")
tc_vdminus500mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_vdminus500mV.csv")
tc_vdplus100mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_1.csv")
tc_vdplus200mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_2.csv")
tc_vdplus300mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_3.csv")
tc_vdplus400mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_4.csv")
tc_vdplus500mV = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/transfer_curve_oect6_5.csv")

# %%
tc_vdminus100mV_v =  tc_vdminus100mV['v_gate']
tc_vdminus100mV_i =  tc_vdminus100mV['i_channel']
tc_vdminus100mV_t =  tc_vdminus100mV['time']

tc_vdminus200mV_v = tc_vdminus200mV['v_gate']
tc_vdminus200mV_t = tc_vdminus200mV['time']
tc_vdminus200mV_i = tc_vdminus200mV['i_channel']

tc_vdminus300mV_v = tc_vdminus300mV['v_gate']
tc_vdminus300mV_t = tc_vdminus300mV['time'] 
tc_vdminus300mV_i = tc_vdminus300mV['i_channel']

tc_vdminus400mV_v = tc_vdminus400mV['v_gate']
tc_vdminus400mV_t = tc_vdminus400mV['time']
tc_vdminus400mV_i = tc_vdminus400mV['i_channel']

tc_vdminus500mV_v = tc_vdminus500mV['v_gate']
tc_vdminus500mV_t = tc_vdminus500mV['time']
tc_vdminus500mV_i = tc_vdminus500mV['i_channel']

tc_vdplus100mV_v = tc_vdplus100mV['v_gate']
tc_vdplus100mV_t = tc_vdplus100mV['time']
tc_vdplus100mV_i =tc_vdplus100mV['i_channel']

tc_vdplus200mV_v = tc_vdplus200mV['v_gate']
tc_vdplus200mV_t = tc_vdplus200mV['time']
tc_vdplus200mV_i = tc_vdplus200mV['i_channel']

tc_vdplus300mV_v =tc_vdplus300mV['v_gate']
tc_vdplus300mV_t =tc_vdplus300mV['time']
tc_vdplus300mV_i = tc_vdplus300mV['i_channel']

tc_vdplus400mV_v = tc_vdplus400mV['v_gate']
tc_vdplus400mV_t = tc_vdplus400mV['time']
tc_vdplus400mV_i = tc_vdplus400mV['i_channel']

tc_vdplus500mV_v = tc_vdplus500mV['v_gate']
tc_vdplus500mV_t = tc_vdplus500mV['time']
tc_vdplus500mV_i = tc_vdplus500mV['i_channel']

# %%
plt.figure()
plt.title("transfer curve")
start = 0
end = -1
plt.plot(tc_vdminus100mV_v[start:end], tc_vdminus100mV_i[start:end], '-', label ='vd @ -0.1 V')
start = 0
end = -1
plt.plot(tc_vdminus200mV_v[start:end], tc_vdminus200mV_i[start:end], '-', label ='vd @ -0.2 V')
start = 0
end = -1
plt.plot(tc_vdminus300mV_v[start:end], tc_vdminus300mV_i[start:end], '-', label ='vd @ -0.3 V')
start = 0
end = -1
plt.plot(tc_vdminus400mV_v[start:end], tc_vdminus400mV_i[start:end], '-', label ='vd @ -0.4 V')
start = 0
end = -1
plt.plot(tc_vdminus500mV_v[start:end], tc_vdminus500mV_i[start:end], '-', label ='vd @ -0.5 V')
start = 0
end = -1
plt.plot(tc_vdplus100mV_v[start:end], tc_vdplus100mV_i[start:end], '-', label ='vd @ 0.1 V')
start = 0
end = -1
plt.plot(tc_vdplus200mV_v[start:end], tc_vdplus200mV_i[start:end], '-', label ='vd @ 0.2 V')
start = 0
end = -1
plt.plot(tc_vdplus300mV_v[start:end], tc_vdplus300mV_i[start:end], '-', label ='vd @ 0.3 V')
start = 0
end = -1
plt.plot(tc_vdplus400mV_v[start:end], tc_vdplus400mV_i[start:end], '-', label ='vd @ 0.4 V')
start = 0
end = -1
plt.plot(tc_vdplus500mV_v[start:end], tc_vdplus500mV_i[start:end], '-', label ='vd @ 0.5 V')
# plt.ylim(310, 313)
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
plt.yscale("linear")
plt.grid()
plt.legend()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("transfer curve")
start = 0
end = -1
ax1.plot(tc_vdminus100mV_t[start:end], tc_vdminus100mV_i[start:end], '-', label ='vd @ -0.1 V')
start = 0
end = -1
ax1.plot(tc_vdminus200mV_t[start:end], tc_vdminus200mV_i[start:end], '-', label ='vd @ -0.2 V')
start = 0
end = -1
ax1.plot(tc_vdminus300mV_t[start:end], tc_vdminus300mV_i[start:end], '-', label ='vd @ -0.3 V')
start = 0
end = -1
ax1.plot(tc_vdminus400mV_t[start:end], tc_vdminus400mV_i[start:end], '-', label ='vd @ -0.4 V')
start = 0
end = -1
ax1.plot(tc_vdminus500mV_t[start:end], tc_vdminus500mV_i[start:end], '-', label ='vd @ -0.5 V')
start = 0
end = -1
ax1.plot(tc_vdplus100mV_t[start:end], tc_vdplus100mV_i[start:end], '-', label ='vd @ 0.1 V')
start = 0
end = -1
ax1.plot(tc_vdplus200mV_t[start:end], tc_vdplus200mV_i[start:end], '-', label ='vd @ 0.2 V')
start = 0
end = -1
ax1.plot(tc_vdplus300mV_t[start:end], tc_vdplus300mV_i[start:end], '-', label ='vd @ 0.3 V')
start = 0
end = -1
ax1.plot(tc_vdplus400mV_t[start:end], tc_vdplus400mV_i[start:end], '-', label ='vd @ 0.4 V')
start = 0
end = -1
ax1.plot(tc_vdplus500mV_t[start:end], tc_vdplus500mV_i[start:end], '-', label ='vd @ 0.5 V')
# plt.ylim(310, 313)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(tc_vdplus500mV_t[start:end], tc_vdplus500mV_v[start:end], '-', label ='v gate')

# %% [markdown]
# ### output curve

# %%
time_samples = []
vd_samples = []
vg_samples = []
current_samples = []
for i in range(0,11):
    file_name = "C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250711/output_curve_oect6_" + str(i+1) + ".csv"
    data = pd.read_csv(file_name)
    time_samples.append(data['time'])
    vd_samples.append(data['v_drain'])
    vg_samples.append(data['v_gate'])
    current_samples.append(data['i_channel'])

# %%
plt.figure()
plt.title("output curve")
for i in range(0,11):
    start = 0
    end = -1
    plt.plot(vd_samples[i][start:end], current_samples[i][start:end], '-', label ='vg @' + str(vg_samples[i][0])+ 'V')

plt.xlabel("Vd [V]")
plt.ylabel("Id [A]")
plt.yscale("linear")
plt.grid()
plt.legend()

# %% [markdown]
# # 20250714

# %%
ecram_pedot_2_20250627_kcl_1Mohm = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250714/ecram_pedot_2_20250627_kcl_1Mohm.csv")

# %%
ecram_pedot_2_20250627_kcl_1Mohm_t = ecram_pedot_2_20250627_kcl_1Mohm['time']
ecram_pedot_2_20250627_kcl_1Mohm_i = ecram_pedot_2_20250627_kcl_1Mohm['i_channel']
ecram_pedot_2_20250627_kcl_1Mohm_v = ecram_pedot_2_20250627_kcl_1Mohm['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram measurement")
start = 0
end = -1
ax1.plot(ecram_pedot_2_20250627_kcl_1Mohm_t[start:end], abs(ecram_pedot_2_20250627_kcl_1Mohm_i)[start:end], '-', label ='measure with vd @ -0.2 V')
ax1.set_xlim(40, 100)
ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_pedot_2_20250627_kcl_1Mohm_t[start:end], ecram_pedot_2_20250627_kcl_1Mohm_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %% [markdown]
# # 20250718 - Shiv devices

# %% [markdown]
# ## transfer curve

# %%
# transfer curve
#  Niels Ag/AgCl, NaCL: 100mM
# Vd: -0.2 V

device_15c5_20250708_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_NaCl.csv")
device_15c5_20250708_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_NaCl.csv")
device_18c6_20250627_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_NaCl.csv")
device_18c6_20250627_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_NaCl.csv")
device_pedot_20250627_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_NaCl.csv")
device_pedot_20250627_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_NaCl.csv")

device_15c5_20250708_1_ich = device_15c5_20250708_1['i_channel']
device_15c5_20250708_1_vg = device_15c5_20250708_1['v_gate']

device_15c5_20250708_2_ich = device_15c5_20250708_2['i_channel']
device_15c5_20250708_2_vg = device_15c5_20250708_2['v_gate']

device_18c6_20250627_1_ich = device_18c6_20250627_1['i_channel']
device_18c6_20250627_1_vg = device_18c6_20250627_1['v_gate']

device_18c6_20250627_2_ich = device_18c6_20250627_2['i_channel']
device_18c6_20250627_2_vg = device_18c6_20250627_2['v_gate']

device_pedot_20250627_1_ich = device_pedot_20250627_1['i_channel']
device_pedot_20250627_1_vg = device_pedot_20250627_1['v_gate']

device_pedot_20250627_2_ich = device_pedot_20250627_2['i_channel']
device_pedot_20250627_2_vg = device_pedot_20250627_2['v_gate']

# %%
plt.figure()
plt.title("output curve, Niels Ag/AgCl, NaCL: 100mM, Vd: -0.2 [V]")
plt.plot(device_15c5_20250708_1_vg, device_15c5_20250708_1_ich, label = '15c5_20250708_1')
plt.plot(device_15c5_20250708_2_vg, device_15c5_20250708_2_ich, label = '15c5_20250708_1')
plt.plot(device_18c6_20250627_1_vg, device_18c6_20250627_1_ich, label = '18c6_20250627_1')
plt.plot(device_18c6_20250627_2_vg, device_18c6_20250627_2_ich, label = '18c6_20250627_2')
plt.plot(device_pedot_20250627_1_vg, device_pedot_20250627_1_ich, label = 'pedot_20250627_1')
plt.plot(device_pedot_20250627_2_vg, device_pedot_20250627_2_ich, label = 'pedot_20250627_2')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
# plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_15c5_20250708_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_KCl.csv")
device_15c5_20250708_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_KCl.csv")
device_18c6_20250627_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_KCl.csv")
device_18c6_20250627_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_KCl.csv")
device_pedot_20250627_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_KCl.csv")
device_pedot_20250627_2 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_KCl.csv")

device_15c5_20250708_1_ich = device_15c5_20250708_1['i_channel']
device_15c5_20250708_1_vg = device_15c5_20250708_1['v_gate']

device_15c5_20250708_2_ich = device_15c5_20250708_2['i_channel']
device_15c5_20250708_2_vg = device_15c5_20250708_2['v_gate']

device_18c6_20250627_1_ich = device_18c6_20250627_1['i_channel']
device_18c6_20250627_1_vg = device_18c6_20250627_1['v_gate']

device_18c6_20250627_2_ich = device_18c6_20250627_2['i_channel']
device_18c6_20250627_2_vg = device_18c6_20250627_2['v_gate']

device_pedot_20250627_1_ich = device_pedot_20250627_1['i_channel']
device_pedot_20250627_1_vg = device_pedot_20250627_1['v_gate']

device_pedot_20250627_2_ich = device_pedot_20250627_2['i_channel']
device_pedot_20250627_2_vg = device_pedot_20250627_2['v_gate']

# %%
plt.figure()
plt.title("output curve, Niels Ag/AgCl, KCl: 100mM, Vd: -0.2 [V]")
plt.plot(device_15c5_20250708_1_vg, device_15c5_20250708_1_ich, label = '15c5_20250708_1')
plt.plot(device_15c5_20250708_2_vg, device_15c5_20250708_2_ich, label = '15c5_20250708_1')
plt.plot(device_18c6_20250627_1_vg, device_18c6_20250627_1_ich, label = '18c6_20250627_1')
plt.plot(device_18c6_20250627_2_vg, device_18c6_20250627_2_ich, label = '18c6_20250627_2')
plt.plot(device_pedot_20250627_1_vg, device_pedot_20250627_1_ich, label = 'pedot_20250627_1')
plt.plot(device_pedot_20250627_2_vg, device_pedot_20250627_2_ich, label = 'pedot_20250627_2')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
# plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_15c5_20250708_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_NaCl.csv")
device_15c5_20250708_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_NaCl.csv")
device_15c5_20250708_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_KCl.csv")
device_15c5_20250708_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_KCl.csv")

device_15c5_20250708_1_NaCl_ich = device_15c5_20250708_1_NaCl['i_channel']
device_15c5_20250708_1_NaCl_vg = device_15c5_20250708_1_NaCl['v_gate']

device_15c5_20250708_2_NaCl_ich = device_15c5_20250708_2_NaCl['i_channel']
device_15c5_20250708_2_NaCl_vg = device_15c5_20250708_2_NaCl['v_gate']

device_15c5_20250708_1_KCl_ich = device_15c5_20250708_1_KCl['i_channel']
device_15c5_20250708_1_KCl_vg = device_15c5_20250708_1_KCl['v_gate']

device_15c5_20250708_2_KCl_ich = device_15c5_20250708_2_KCl['i_channel']
device_15c5_20250708_2_KCl_vg = device_15c5_20250708_2_KCl['v_gate']

# %%
plt.figure()
plt.title("output curve, Niels Ag/AgCl, device_15c5_20250708, Vd: -0.2 [V]")
plt.plot(device_15c5_20250708_1_NaCl_vg, device_15c5_20250708_1_NaCl_ich, label = 'NaCl 100mM, device 1')
plt.plot(device_15c5_20250708_2_NaCl_vg, device_15c5_20250708_2_NaCl_ich, label = 'NaCl 100mM, device 2')
plt.plot(device_15c5_20250708_1_KCl_vg, device_15c5_20250708_1_KCl_ich, label = 'KCl 100mM, device 1')
plt.plot(device_15c5_20250708_2_KCl_vg, device_15c5_20250708_2_KCl_ich, label = 'KCl 100mM, device 2')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
# plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_18c6_20250627_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_NaCl.csv")
device_18c6_20250627_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_NaCl.csv")
device_18c6_20250627_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_KCl.csv")
device_18c6_20250627_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_KCl.csv")

device_18c6_20250627_1_NaCl_ich = device_18c6_20250627_1_NaCl['i_channel']
device_18c6_20250627_1_NaCl_vg = device_18c6_20250627_1_NaCl['v_gate']

device_18c6_20250627_2_NaCl_ich = device_18c6_20250627_2_NaCl['i_channel']
device_18c6_20250627_2_NaCl_vg = device_18c6_20250627_2_NaCl['v_gate']

device_18c6_20250627_1_KCl_ich = device_18c6_20250627_1_KCl['i_channel']
device_18c6_20250627_1_KCl_vg = device_18c6_20250627_1_KCl['v_gate']

device_18c6_20250627_2_KCl_ich = device_18c6_20250627_2_KCl['i_channel']
device_18c6_20250627_2_KCl_vg = device_18c6_20250627_2_KCl['v_gate']

# %%
plt.figure()
plt.title("output curve, Niels Ag/AgCl, device_18c6_20250627, Vd: -0.2 [V]")
plt.plot(device_18c6_20250627_1_NaCl_vg, device_18c6_20250627_1_NaCl_ich, label = 'NaCl 100mM, device 1')
plt.plot(device_18c6_20250627_2_NaCl_vg, device_18c6_20250627_2_NaCl_ich, label = 'NaCl 100mM, device 2')
plt.plot(device_18c6_20250627_1_KCl_vg, device_18c6_20250627_1_KCl_ich, label = 'KCl 100mM, device 1')
plt.plot(device_18c6_20250627_2_KCl_vg, device_18c6_20250627_2_KCl_ich, label = 'KCl 100mM, device 2')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
# plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_pedot_20250627_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_NaCl.csv")
device_pedot_20250627_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_NaCl.csv")
device_pedot_20250627_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_KCl.csv")
device_pedot_20250627_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_KCl.csv")

device_pedot_20250627_1_NaCl_ich = device_pedot_20250627_1_NaCl['i_channel']
device_pedot_20250627_1_NaCl_vg = device_pedot_20250627_1_NaCl['v_gate']

device_pedot_20250627_2_NaCl_ich = device_pedot_20250627_2_NaCl['i_channel']
device_pedot_20250627_2_NaCl_vg = device_pedot_20250627_2_NaCl['v_gate']

device_pedot_20250627_1_KCl_ich = device_pedot_20250627_1_KCl['i_channel']
device_pedot_20250627_1_KCl_vg = device_pedot_20250627_1_KCl['v_gate']

device_pedot_20250627_2_KCl_ich = device_pedot_20250627_2_KCl['i_channel']
device_pedot_20250627_2_KCl_vg = device_pedot_20250627_2_KCl['v_gate']

# %%
plt.figure()
plt.title("output curve, Niels Ag/AgCl, device_pedot_20250627, Vd: -0.2 [V]")
plt.plot(device_pedot_20250627_1_NaCl_vg, device_pedot_20250627_1_NaCl_ich, label = 'NaCl 100mM, device 1')
plt.plot(device_pedot_20250627_2_NaCl_vg, device_pedot_20250627_2_NaCl_ich, label = 'NaCl 100mM, device 2')
plt.plot(device_pedot_20250627_1_KCl_vg, device_pedot_20250627_1_KCl_ich, label = 'KCl 100mM, device 1')
plt.plot(device_pedot_20250627_2_KCl_vg, device_pedot_20250627_2_KCl_ich, label = 'KCl 100mM, device 2')
plt.xlabel("Vg [V]")
plt.ylabel("Id [A]")
# plt.yscale("linear")
plt.grid()
plt.legend()

# %%
# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_pedot_20250627_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_NaCl.csv")
device_pedot_20250627_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_NaCl.csv")
device_pedot_20250627_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_1_KCl.csv")
device_pedot_20250627_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_pedot_20250627_2_KCl.csv")

device_pedot_20250627_1_NaCl_ich = device_pedot_20250627_1_NaCl['i_channel']
device_pedot_20250627_1_NaCl_vg = device_pedot_20250627_1_NaCl['v_gate']

device_pedot_20250627_2_NaCl_ich = device_pedot_20250627_2_NaCl['i_channel']
device_pedot_20250627_2_NaCl_vg = device_pedot_20250627_2_NaCl['v_gate']

device_pedot_20250627_1_KCl_ich = device_pedot_20250627_1_KCl['i_channel']
device_pedot_20250627_1_KCl_vg = device_pedot_20250627_1_KCl['v_gate']

device_pedot_20250627_2_KCl_ich = device_pedot_20250627_2_KCl['i_channel']
device_pedot_20250627_2_KCl_vg = device_pedot_20250627_2_KCl['v_gate']

# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_18c6_20250627_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_NaCl.csv")
device_18c6_20250627_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_NaCl.csv")
device_18c6_20250627_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_1_KCl.csv")
device_18c6_20250627_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_18c6_20250627_2_KCl.csv")

device_18c6_20250627_1_NaCl_ich = device_18c6_20250627_1_NaCl['i_channel']
device_18c6_20250627_1_NaCl_vg = device_18c6_20250627_1_NaCl['v_gate']

device_18c6_20250627_2_NaCl_ich = device_18c6_20250627_2_NaCl['i_channel']
device_18c6_20250627_2_NaCl_vg = device_18c6_20250627_2_NaCl['v_gate']

device_18c6_20250627_1_KCl_ich = device_18c6_20250627_1_KCl['i_channel']
device_18c6_20250627_1_KCl_vg = device_18c6_20250627_1_KCl['v_gate']

device_18c6_20250627_2_KCl_ich = device_18c6_20250627_2_KCl['i_channel']
device_18c6_20250627_2_KCl_vg = device_18c6_20250627_2_KCl['v_gate']

# Compare NaCl, KCl of the same device
# transfer curve
#  Niels Ag/AgCl, KCL: 100mM
# Vd: -0.2 V

device_15c5_20250708_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_NaCl.csv")
device_15c5_20250708_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_NaCl.csv")
device_15c5_20250708_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_1_KCl.csv")
device_15c5_20250708_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/transfer_curve_15c5_20250708_2_KCl.csv")

device_15c5_20250708_1_NaCl_ich = device_15c5_20250708_1_NaCl['i_channel']
device_15c5_20250708_1_NaCl_vg = device_15c5_20250708_1_NaCl['v_gate']

device_15c5_20250708_2_NaCl_ich = device_15c5_20250708_2_NaCl['i_channel']
device_15c5_20250708_2_NaCl_vg = device_15c5_20250708_2_NaCl['v_gate']

device_15c5_20250708_1_KCl_ich = device_15c5_20250708_1_KCl['i_channel']
device_15c5_20250708_1_KCl_vg = device_15c5_20250708_1_KCl['v_gate']

device_15c5_20250708_2_KCl_ich = device_15c5_20250708_2_KCl['i_channel']
device_15c5_20250708_2_KCl_vg = device_15c5_20250708_2_KCl['v_gate']


fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex= True)
ax1.set_title("ecram 15c5 ")
start = 0
end = -1
ax1.plot(device_15c5_20250708_1_NaCl_vg[start:end], device_15c5_20250708_1_NaCl_ich[start:end], '-', label ='15c5_1_NaCl')
ax1.plot(device_15c5_20250708_2_NaCl_vg[start:end], device_15c5_20250708_2_NaCl_ich[start:end], '-', label ='15c5_2_NaCl')
ax1.plot(device_15c5_20250708_1_KCl_vg[start:end], device_15c5_20250708_1_KCl_ich[start:end], '-', label ='15c5_1_KCl')
ax1.plot(device_15c5_20250708_2_KCl_vg[start:end], device_15c5_20250708_2_KCl_ich[start:end], '-', label ='15c5_2_KCl')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
# ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
# ax1.set_yscale("linear")
# ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.set_title("ecram 18c6 ")
start = 0
end = -1
ax2.plot(device_18c6_20250627_1_NaCl_vg[start:end], device_18c6_20250627_1_NaCl_ich[start:end], '-', label ='18c6_1_NaCl')
ax2.plot(device_18c6_20250627_2_NaCl_vg[start:end], device_18c6_20250627_2_NaCl_ich[start:end], '-', label ='18c6_2_NaCl')
ax2.plot(device_18c6_20250627_1_KCl_vg[start:end], device_18c6_20250627_1_KCl_ich[start:end], '-', label ='18c6_1_KCl')
ax2.plot(device_18c6_20250627_2_KCl_vg[start:end], device_18c6_20250627_2_KCl_ich[start:end], '-', label ='18c6_2_KCl')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
# ax1.set_xlabel("time [s]")
ax2.set_ylabel("Id [A]")
# ax1.set_yscale("linear")
# ax1.grid()
ax2.legend()

start = 0
end = -1
ax3.set_title("ecram pedot ")
start = 0
end = -1
ax3.plot(device_pedot_20250627_1_NaCl_vg[start:end], device_pedot_20250627_1_NaCl_ich[start:end], '-', label ='pedot_1_NaCl')
ax3.plot(device_pedot_20250627_2_NaCl_vg[start:end], device_pedot_20250627_2_NaCl_ich[start:end], '-', label ='pedot_2_NaCl')
ax3.plot(device_pedot_20250627_1_KCl_vg[start:end], device_pedot_20250627_1_KCl_ich[start:end], '-', label ='pedot_1_KCl')
ax3.plot(device_pedot_20250627_2_KCl_vg[start:end], device_pedot_20250627_2_KCl_ich[start:end], '-', label ='pedot_2_KCl')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
# ax1.set_xlabel("time [s]")
ax3.set_ylabel("Id [A]")
# ax1.set_yscale("linear")
# ax1.grid()
ax3.legend()

# %% [markdown]
# ## ecram

# %% [markdown]
# ### ecram of individual device

# %%
device_15c5_20250708_1 = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_1_NaCl_1MohmGate_2.csv")
ecram_t = device_15c5_20250708_1['time']
ecram_i = device_15c5_20250708_1['i_channel']
ecram_v = device_15c5_20250708_1['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 15c5_20250708_1_NaCl_1MohmGate ")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_1_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 15c5_20250708_1_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_2_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 15c5_20250708_2_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_2_NaCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 15c5_20250708_2_NaCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_18c6_20250627_1_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 18c6_20250627_1_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_18c6_20250627_1_NaCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 18c6_20250627_1_NaCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_18c6_20250627_2_NaCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 18c6_20250627_2_NaCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_18c6_20250627_2_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram 18c6_20250627_2_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_1_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram pedot_20250627_1_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_2_KCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram pedot_20250627_2_KCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_1_NaCl_1MohmGate_2.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram pedot_20250627_1_NaCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %%
device = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_2_NaCl_1MohmGate_1.csv")

ecram_t = device['time']
ecram_i = device['i_channel']
ecram_v = device['v_gate']

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.set_title("ecram pedot_20250627_2_NaCl_1MohmGate")
start = 0
end = -1
ax1.plot(ecram_t[start:end], abs(ecram_i)[start:end], '-', label ='measure with vd @ -0.2 V')
# ax1.set_xlim(40, 100)
# ax1.set_ylim(900e-7, 930e-7)
ax1.set_xlabel("time [s]")
ax1.set_ylabel("Id [A]")
ax1.set_yscale("linear")
ax1.grid()
ax1.legend()

start = 0
end = -1
ax2.plot(ecram_t[start:end], ecram_v[start:end], '-', label ='v gate')
ax2.set_xlabel("time [s]")
ax2.set_ylabel("Vgate [A]")
ax2.set_yscale("linear")
ax2.grid()
ax2.legend()

# %% [markdown]
# ### rate of change comparison

# %%
import numpy as np

# %%
device_15c5_20250708_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_1_NaCl_1MohmGate_2.csv")
device_15c5_20250708_2_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_2_KCl_1MohmGate_2.csv")
device_15c5_20250708_2_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_15c5_20250708_2_NaCl_1MohmGate_2.csv")
device_pedot_20250627_1_KCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_1_KCl_1MohmGate_2.csv")
device_pedot_20250627_1_NaCl = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250718/ecram_pedot_20250627_1_NaCl_1MohmGate_2.csv")

ecram_t_15c5_20250708_1_NaCl = device_15c5_20250708_1_NaCl['time']
ecram_i_15c5_20250708_1_NaCl = device_15c5_20250708_1_NaCl['i_channel']

ecram_t_15c5_20250708_2_KCl = device_15c5_20250708_2_KCl['time']
ecram_i_15c5_20250708_2_KCl = device_15c5_20250708_2_KCl['i_channel']

ecram_t_15c5_20250708_2_NaCl = device_15c5_20250708_2_NaCl['time']
ecram_i_15c5_20250708_2_NaCl = device_15c5_20250708_2_NaCl['i_channel']

ecram_t_pedot_20250627_1_KCl = device_pedot_20250627_1_KCl['time']
ecram_i_pedot_20250627_1_KCl = device_pedot_20250627_1_KCl['i_channel']

ecram_t_pedot_20250627_1_NaCl = device_pedot_20250627_1_NaCl['time']
ecram_i_pedot_20250627_1_NaCl = device_pedot_20250627_1_NaCl['i_channel']

plt.figure()
plt.title("rate of change comparison, dc shift")
start = 100
end = -1
plt.plot(ecram_t_15c5_20250708_1_NaCl[start:end], ecram_i_15c5_20250708_1_NaCl[start:end] - np.mean(ecram_i_15c5_20250708_1_NaCl[start:end]), label = '15c5_1_NaCl')
plt.plot(ecram_t_15c5_20250708_2_KCl[start:end], ecram_i_15c5_20250708_2_KCl[start:end]- np.mean(ecram_i_15c5_20250708_2_KCl[start:end]), label = '15c5_2_KCl')
plt.plot(ecram_t_15c5_20250708_2_NaCl[start:end], ecram_i_15c5_20250708_2_NaCl[start:end]- np.mean(ecram_i_15c5_20250708_2_NaCl[start:end]), label = '15c5_2_NaCl')
plt.plot(ecram_t_pedot_20250627_1_KCl[start:end], ecram_i_pedot_20250627_1_KCl[start:end]- np.mean(ecram_i_pedot_20250627_1_KCl[start:end]), label = 'pedot_1_KCl')
plt.plot(ecram_t_pedot_20250627_1_NaCl[start:end], ecram_i_pedot_20250627_1_NaCl[start:end]- np.mean(ecram_i_pedot_20250627_1_NaCl[start:end]), label = 'pedot_1_NaCl')
plt.xlim(20, 35)
# plt.ylim(-2e-6, 2e-6)
plt.legend()
plt.xlabel('time [s]')
plt.ylabel('Id [A]')
# Out:
# Text(0, 0.5, 'Id [A]')

# %%
np.mean(ecram_i_15c5_20250708_1_NaCl[start:end])
# Out:
# np.float64(-0.00016142646722186633)

# %%
plt.figure()
plt.title("rate of change comparison, dc shift, time shift")
start = 1500
end = len(ecram_t_15c5_20250708_1_NaCl) - 2000
plt.plot(ecram_t_15c5_20250708_1_NaCl[start:end], ecram_i_15c5_20250708_1_NaCl[start:end] - np.mean(ecram_i_15c5_20250708_1_NaCl[start:end]), label = '15c5_1_NaCl')
start = 700
end = len(ecram_t_15c5_20250708_2_KCl) - 1000
plt.plot(ecram_t_15c5_20250708_2_KCl[start:end] + 30, ecram_i_15c5_20250708_2_KCl[start:end]- np.mean(ecram_i_15c5_20250708_2_KCl[start:end]), label = '15c5_2_KCl')
start = 1500
end = len(ecram_t_15c5_20250708_2_NaCl) - 3000
plt.plot(ecram_t_15c5_20250708_2_NaCl[start:end], ecram_i_15c5_20250708_2_NaCl[start:end]- np.mean(ecram_i_15c5_20250708_2_NaCl[start:end]), label = '15c5_2_NaCl')
start = 700
end = len(ecram_t_pedot_20250627_1_KCl) - 900
plt.plot(ecram_t_pedot_20250627_1_KCl[start:end] + 30, ecram_i_pedot_20250627_1_KCl[start:end]- np.mean(ecram_i_pedot_20250627_1_KCl[start:end]), label = 'pedot_1_KCl')
start = 1500
end = len(ecram_t_pedot_20250627_1_NaCl) - 1500
plt.plot(ecram_t_pedot_20250627_1_NaCl[start:end], ecram_i_pedot_20250627_1_NaCl[start:end]- np.mean(ecram_i_pedot_20250627_1_NaCl[start:end]), label = 'pedot_1_NaCl')
plt.xlim(82, 89.5)
plt.ylim(-1e-6, 1.5e-6)
plt.legend()
plt.xlabel('time [s]')
plt.ylabel('Id [A]')
# Out:
# Text(0, 0.5, 'Id [A]')

# %% [markdown]
# # 20250723

# %%
yorigin=4294967295.0
yref=4294967295.0
yincr=9.9e+37

# %%
data = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250723/trace_2.csv")

t = data['time']
v = data['volts']

# v = (v - yorigin - yref)*yincr
start = 0
end = 900000
plt.plot(t[start:end],v[start:end])

# %% [markdown]
# # 20250724

# %%
data = pd.read_csv("C:/Users/20245580/LabCode/Codes_For_Experiments/exp_data/20250724/trace_after_5dp_4.csv")

t = data['time']
v = data['volts']

# v = (v - yorigin - yref)*yincr
start = 0
end = -1
plt.plot(t[start:end],v[start:end])
